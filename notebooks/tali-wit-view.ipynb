# %%
import pyarrow as pa
import pyarrow.parquet as pq
import pyarrow.dataset as ds
from rich import print
from rich.traceback import install

install()
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7effedb3a260>>

# %%
from dataclasses import dataclass
import pathlib
from typing import List

@dataclass
class TALISchema:
    wit_idx: pa.int64()
    term_idx: pa.int64()
    sort_type: pa.string()
    age_restricted: pa.bool_()
    author: pa.string()
    channel_id: pa.string()
    channel_url: pa.string()
    description: pa.string()
    embed_url: pa.string()
    keywords: pa.list_(pa.string())
    length: pa.int64()
    publish_date: pa.timestamp("us")
    thumbnail_url: pa.string()
    title: pa.string()
    video_id: pa.string()
    video_store_filepath: pa.string()
    views: pa.string()
    watch_url: pa.string()

# print(TALISchema.__dict__["__annotations__"])
tali_schema = list(TALISchema.__dict__["__annotations__"].items())
tali_schema = pa.schema(tali_schema)
table_filepath = pathlib.Path("/data/datasets/tali-wit-2-1-buckets/dataset.parquet/relevance/1/")
taliwit_table = ds.dataset(table_filepath, schema=tali_schema).to_table()

# %%
df = taliwit_table.to_pandas()

# %%
import pandas as pd
from itables import init_notebook_mode
init_notebook_mode(all_interactive=True)
# Out:
# <script type="module">
#   window.__itables_render = async (table_id, dt_args) => {
#     await initializeDataTables();
#     $(table_id).DataTable(dt_args);
#   };
#
#   async function initializeDataTables() {
#     if ($.prototype.DataTable) {
#       return;
#     }
#     const dt = (await import("data:text/javascript;base64,...")).default;
#     dt(window.$);
#   }
# </script>
# <style>table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{height:1em;width:1em;margin-top:-9px;display:inline-block;color:white;border:.15em solid white;border-radius:1em;box-shadow:0 0 .2em #444;box-sizing:content-box;text-align:center;text-indent:0 !important;font-family:"Courier New",Courier,monospace;line-height:1em;content:"+";background-color:#31b131}table.dataTable tr.dt-hasChild td.dt-control:before{content:"-";background-color:#d33333}table.dataTable thead>tr>th.sorting,table.dataTable thead>tr>th.sorting_asc,table.dataTable thead>tr>th.sorting_desc,table.dataTable thead>tr>th.sorting_asc_disabled,table.dataTable thead>tr>th.sorting_desc_disabled,table.dataTable thead>tr>td.sorting,table.dataTable thead>tr>td.sorting_asc,table.dataTable thead>tr>td.sorting_desc,table.dataTable thead>tr>td.sorting_asc_disabled,table.dataTable thead>tr>td.sorting_desc_disabled{cursor:pointer;position:relative;padding-right:26px}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after{position:absolute;display:block;opacity:.125;right:10px;line-height:9px;font-size:.9em}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:before{bottom:50%;content:"▴"}table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:after{top:50%;content:"▾"}table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:after{opacity:.6}table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting_asc_disabled:before{display:none}table.dataTable thead>tr>th:active,table.dataTable thead>tr>td:active{outline:none}div.dataTables_scrollBody table.dataTable thead>tr>th:before,div.dataTables_scrollBody table.dataTable thead>tr>th:after,div.dataTables_scrollBody table.dataTable thead>tr>td:before,div.dataTables_scrollBody table.dataTable thead>tr>td:after{display:none}div.dataTables_processing{position:absolute;top:50%;left:50%;width:200px;margin-left:-100px;margin-top:-26px;text-align:center; ...

# %%
df
# Out:
# WARNING:itables.downsample:showing 455x18 of 637x18 as nbytes=91728>65536=maxBytes. See https://mwouts.github.io/itables/downsampling.html
# /opt/conda/envs/tali-collector/lib/python3.10/site-packages/itables/javascript.py:118: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   formatted_df.iloc[:, j] = np.array(fmt.format_array(x.values, None))
#      wit_idx  term_idx  sort_type  age_restricted  \
# 0       1001         0  relevance           False
# 1       1001         1  relevance           False
# 2       1002         0  relevance           False
# 3       1002         1  relevance           False
# 4       1003         0  relevance           False
# ..       ...       ...        ...             ...
# 632     1994         1  relevance           False
# 633     1995         0  relevance           False
# 634     1997         1  relevance           False
# 635     1999         0  relevance           False
# 636     1999         1  relevance           False
#
#                                        author                channel_id  \
# 0     CCD - St. Mary's Catholic Church, Dubai  UCuT6BEakFPo_8u33Ns5pU2A
# 1                          Catholic Deep Dive  UCxNYsQPs1hoDs5rL8hy6FYg
# 2                      Professor Curtis Meyer  UCbRal13mz8zToBrNG0X3ExQ
# 3                      Professor Curtis Meyer  UCbRal13mz8zToBrNG0X3ExQ
# 4    Cookie & The Hayden’s - UK eBay Reseller  UCDkP3zM6OnGFawYTca0F2gQ
# ..                                        ...                       ...
# 632                                    ANU TV  UCxzvNYT-17mjYJMuDzGx7AA
# 633                                videobiker  UC2FeHc4_GJYEwZtPut6QjQA
# 634                           Cirrus Aircraft  UCTb2omHTFLyoY8dEdFOQN4w
# 635                       The Beginners Bible  UCiM9mWNxTWpKY-V9Eb9TfkA
# 636                       Salisbury Cathedral  UCNICHZ40eOMdPi4oAJXl78g
#
#                                            channel_url  \
# 0    https://www.youtube.com/channel/UCuT6BEakFPo_8...
# 1    https://www.youtube.com/channel/UCxNYsQPs1hoDs...
# 2    https://www.youtube.com/channel/UCbRal13mz8zTo...
# 3    https://www.youtube.com/channel/UCbRal13mz8zTo...
# 4    https://www.youtube.com/channel/UCDkP3zM6OnGFa...
# ..                                                 ...
# 632  https://www.youtube.com/channel/UCxzvNYT-17mjY...
# 633  https://www.youtube.com/channel/UC2FeHc4_GJYEw...
# 634  https://www.youtube.com/channel/UCTb2omHTFLyoY...
# 635  https://www.youtube.com/channel/UCiM9mWNxTWpKY...
# 636  https://www.youtube.com/channel/UCNICHZ40eOMdP...
#
#                                            description  \
# 0
# 1    Founder of Missionaries of the Precious Blood ...
# 2                         Negative Impedance Converter
# 3                         Negative Impedance Converter
# 4    Probably THE BEST Car Boot Sale In The North W...
# ..                                                 ...
# 632  Nicholas Coppel is RAMSI's Special Coordinator...
# 633  1937 Leo McCarey, Cary Grant, Irene Dunne, Ral...
# 634  Our Vision Jet is now more capable and connect...
# 635  Subscribe our channel: http://bit.ly/1MeurZH\n...
# 636  Four rope access conservators from Vitruvius B...
#
#                                      embed_url  \
# 0    https://www.youtube.com/embed/nHSmMyLFf7A
# 1    https://www.youtube.com/embed/FhYxvNXPK6I
# 2    https://www.youtube.com/embed/cImGOXkDY1o
# 3    https://www.youtube.com/embed/cImGOXkDY1o
# 4    https://www.youtube.com/embed/s5CHepSZFS0
# ..                                         ...
# 632  https://www.youtube.com/embed/SZIEOdAu-7w
# 633  https://www.youtube.com/embed/MI7Wk0BjNDo
# 634  https://www.youtube.com/embed/v2cPb5Dl_P8
# 635  https://www.youtube.com/embed/65KgsHvFKd4
# 636  https://www.youtube.com/embed/3wBkvFcAUvg
#
#                                               keywords  length publish_date  \
# 0                                                   []    6605   2022-05-07
# 1                                                   []     359   2021-02-13
# 2                                            [9-30-17]     342   2018-01-17
# 3                                            [9-30-17]     342   2018-01-17
# 4    [uk reseller, ebay reseller, car boot chris, s...    3489   2022-04-02
# ..                                                 ...     ...          ...
# 632  [Australian, National, University, ANU, Asia, ...     288   2012-07-24
# 633                                                 []     336   2021-10-09
# 634                                                 []     228   2021-07-20
# 635  [The Bible (Religious Text), Moses (Religious ...    1598   2014-10-14
# 636  [Medieval building, building restoration, rope...     207   2019-06-07
#
#                                          thumbnail_url  \
# 0    https://i.ytimg.com/vi/nHSmMyLFf7A/sddefault.j...
# 1     https://i.ytimg.com/vi/FhYxvNXPK6I/sddefault.jpg
# 2     https://i.ytimg.com/vi/cImGOXkDY1o/sddefault.jpg
# 3     https://i.ytimg.com/vi/cImGOXkDY1o/sddefault.jpg
# 4     https://i.ytimg.com/vi/s5CHepSZFS0/sddefault.jpg
# ..                                                 ...
# 632   https://i.ytimg.com/vi/SZIEOdAu-7w/sddefault.jpg
# 633   https://i.ytimg.com/vi/MI7Wk0BjNDo/sddefault.jpg
# 634  https://i.ytimg.com/vi/v2cPb5Dl_P8/sddefault.j...
# 635   https://i.ytimg.com/vi/65KgsHvFKd4/sddefault.jpg
# 636   https://i.ytimg.com/vi/3wBkvFcAUvg/sddefault.jpg
#
#                                                  title     video_id  \
# 0    First Holy Communion | St. Mary's Catholic Chu...  nHSmMyLFf7A
# 1                    St  Gaspar del Bufalo, October 21  FhYxvNXPK6I
# 2                     Negative Impedance Converter—NIC  cImGOXkDY1o
# 3                     Negative Impedance Converter—NIC  cImGOXkDY1o
# 4    Probably THE BEST Car Boot Sale In The North W...  s5CHepSZFS0
# ..                                                 ...          ...
# 632  Transition of the Regional Assistance Mission ...  SZIEOdAu-7w
# 633               The Awful Truth — "Flat on His Puss"  MI7Wk0BjNDo
# 634                     Introducing our G2+ Vision Jet  v2cPb5Dl_P8
# 635               The Story of Moses - Beginners Bible  65KgsHvFKd4
# 636      Conservators Abseil Down West Front June 2019  3wBkvFcAUvg
#
#                                   video_store_filepath    views  \
# 0    /mnt/nas/datasets/tali-wit-2-1/all/1001/nHSmMy...     5866
# 1    /mnt/nas/datasets/tali-wit-2-1/all/1001/FhYxvN...       82
# 2    /mnt/nas/datasets/tali-wit-2-1/all/1002/cImGOX...     4193
# 3    /mnt/nas/datasets/tali-wit-2-1/all/1002/cImGOX...     4193
# 4    /mnt/nas/datasets/tali-wit-2-1/all/1003/s5CHep...    12326
# ..                                                 ...      ...
# 632  /mnt/nas/datasets/tali-wit-2-1/all/1994/SZIEOd...      606
# 633  /mnt/nas/datasets/tali-wit-2-1/all/1995/MI7Wk0...     2020
# 634  /mnt/nas/datasets/tali-wit-2-1/all/1997/v2cPb5...   204493
# 635  /mnt/nas/datasets/tali-wit-2-1/all/1999/65KgsH...  3027711
# 636  /mnt/nas/datasets/tali-wit-2-1/all/1999/3wBkvF...      500
#
#                                    watch_url
# 0    https://youtube.com/watch?v=nHSmMyLFf7A
# 1    https://youtube.com/watch?v=FhYxvNXPK6I
# 2    https://youtube.com/watch?v=cImGOXkDY1o
# 3    https://youtube.com/watch?v=cImGOXkDY1o
# 4    https://youtube.com/watch?v=s5CHepSZFS0
# ..                                       ...
# 632  https://youtube.com/watch?v=SZIEOdAu-7w
# 633  https://youtube.com/watch?v=MI7Wk0BjNDo
# 634  https://youtube.com/watch?v=v2cPb5Dl_P8
# 635  https://youtube.com/watch?v=65KgsHvFKd4
# 636  https://youtube.com/watch?v=3wBkvFcAUvg
#
# [637 rows x 18 columns]
